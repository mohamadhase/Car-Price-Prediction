# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('xi-Cubic-B-spline-Exact-Absolute-Error.csv')
df
# Out:
#       xi     Cubic  B-spline     Exact  Absolute  Error  Unnamed: 6
# 0   0.00  0.000000  0.000000  0.000000       NaN    NaN         NaN
# 1   0.05  0.027535  0.027537  0.000002       NaN    NaN         NaN
# 2   0.10  0.054250  0.054257  0.000007       NaN    NaN         NaN
# 3   0.15  0.080699  0.080713  0.000014       NaN    NaN         NaN
# 4   0.20  0.107405  0.107429  0.000024       NaN    NaN         NaN
# 5   0.25  0.134870  0.134903  0.000034       NaN    NaN         NaN
# 6   0.30  0.163581  0.163626  0.000044       NaN    NaN         NaN
# 7   0.35  0.194022  0.194077  0.000055       NaN    NaN         NaN
# 8   0.40  0.226677  0.226741  0.000065       NaN    NaN         NaN
# 9   0.45  0.262037  0.262111  0.000074       NaN    NaN         NaN
# 10  0.50  0.300613  0.300695  0.000082       NaN    NaN         NaN
# 11  0.55  0.342936  0.343024  0.000088       NaN    NaN         NaN
# 12  0.60  0.389564  0.389657  0.000093       NaN    NaN         NaN
# ...

# %%
plt.scatter(df['xi'], df['Cubic'], label='Cubic')
plt.scatter(df['xi'], df['B-spline'], label='B-spline')
plt.scatter(df['xi'], df['Exact'], label='Exact')
